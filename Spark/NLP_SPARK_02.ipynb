# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pyspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyspark
#   Downloading pyspark-3.3.0.tar.gz (281.3 MB)
#      |████████████████████████████████| 281.3 MB 41 kB/s
# Collecting py4j==0.10.9.5
#   Downloading py4j-0.10.9.5-py2.py3-none-any.whl (199 kB)
#      |████████████████████████████████| 199 kB 44.5 MB/s
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.3.0-py2.py3-none-any.whl size=281764026 sha256=093fabd948b97b9c88bd3ba268ae910ef877479bb6af9b4eb61154dba11f181e
#   Stored in directory: /root/.cache/pip/wheels/7a/8e/1b/f73a52650d2e5f337708d9f6a1750d451a7349a867f928b885
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9.5 pyspark-3.3.0

# %%
import html
from pyspark.sql import functions as f
from pyspark.sql.functions import udf
from pyspark.sql import SparkSession
from pyspark.sql import DataFrame

spark = SparkSession.builder.getOrCreate()

RAW_PATH = "/content/drive/MyDrive/sentiment-140-training-data/RAW"
CLEAN_PATH = "/content/drive/MyDrive/sentiment-140-training-data/CLEAN"

# %%
# Have a first look at the data
raw_data = spark.read.csv(RAW_PATH)  # .cache()

# Let's look at 50 rows of data
raw_data.show(50, False)
# Out:
# +----------+----------------------------+--------+---------------+-----------------------------------------------------------------------------------------------------------------------------------------+--------+
# |_c0       |_c1                         |_c2     |_c3            |_c4                                                                                                                                      |polarity|
# +----------+----------------------------+--------+---------------+-----------------------------------------------------------------------------------------------------------------------------------------+--------+
# |2326691715|Thu Jun 25 07:23:01 PDT 2009|NO_QUERY|androslee      |aw snap, win7 discounts tomorrow?  goodbye checkbook   http://tr.im/pIT5                                                                 |0.0     |
# |2050459563|Fri Jun 05 18:42:24 PDT 2009|NO_QUERY|ShannonRaeP    |not having a good day today feeling depressed and un motivated all alone all day today                                                   |0.0     |
# |2257676117|Sat Jun 20 14:42:54 PDT 2009|NO_QUERY|sweett8        |watchinG paRis hiltOn my new BFF [wii] haha anD jOb                                                                                      |0.0     |
# |2205642391|Wed Jun 17 05:09:57 PDT 2009|NO_QUERY|nuttychris     |@nelsonmaud fucking amazing just got shit loadsa work to do  haha                                                                        |0.0     |
# |2014908397|Wed Jun 03 03:05:02 PDT 2009|NO_QUERY|mishok13       |huh, pylint doesn't handle yield expressions, crashes --&gt; my flymake+pylint combo can not be used for coroutines                      |0.0     |
# |2260481608|Sat Jun 20 19:17:15 PDT 2009|NO_QUERY|LarynHundley   |wants to get out but it's a little late                                                                                                  |0.0     |
# |1564340958|Mon Apr 20 03:00:43 PDT 2009|NO_QUERY|AlexJReid      |@littlecharva Thought I noticed some chemistry.                                                                                          |0.0     |
# |2072184787|Sun Jun 07 20:33:05 PDT 2009|NO_QUERY|CliqueFix      |Finally figured out how to make Roller coaster tycoon HQ. but it's small                                                                 |0.0     |
# |2298570025|Tue Jun 23 11:50:34 PDT 2009|NO_QUERY|CChriss92      |watchin TV.... but it's alomst time to go to sleep  miley u rock ;) peace                                                                |0.0     |
# |2259683279|Sat Jun 20 17:59:39 PDT 2009|NO_QUERY|deabodanese    |@tommcfly can you wish happy birthday @milaitsme ? PLEASE, stop reply to demi and wish happy birthday to her                             |0.0     |
# |1753565812|Sun May 10 02:16:49 PDT 2009|NO_QUERY|tattoogoddess  |@rustyrockets i need a date to zombie prom in portland oregon. my date canceled want and could you be my date                            |0.0     |
# |1976173745|Sat May 30 16:44:56 PDT 2009|NO_QUERY|vampirate88    |Ok i'll try to upload my pic... hope it works, if not i need help....                                                                    |0.0     |
# |2220630292|Thu Jun 18 03:34:40 PDT 2009|NO_QUERY|kallymarie09   |@BattleshipMatt  rudeness                                                                                                                |0.0     |
# |1970459568|Sat May 30 03:57:21 PDT 2009|NO_QUERY|VikiCollins    |www.ghostbustersishiring.com - Seriously?! WHY did I have to be born in the UK?! Only open to US &amp; Canada! I want to cry!            |0.0     |
# +----------+----------------------------+--------+---------------+-----------------------------------------------------------------------------------------------------------------------------------------+--------+
# only showing top 50 rows

# %%
schema_ddl = """
polarity STRING COMMENT "the polarity of the tweet (0 = negative, 2 = neutral, 4 = positive)",
id LONG COMMENT "the id of the tweet (2087)",
date TIMESTAMP COMMENT "the date of the tweet (Sat May 16 23:58:44 UTC 2009)",
query STRING COMMENT "the query (lyx). If there is no query, then this value is NO_QUERY.",
user string COMMENT "the user that tweeted (robotickilldozr)",
text string COMMENT "the text of the tweet (Lyx is cool)"
"""

#spark_reader = spark.read.schema(schema_ddl)

# %%
simple_date_format = "EEE MMM dd HH:mm:ss zzz yyyy"

raw_data = spark.read.csv(RAW_PATH, inferSchema=True )

raw_data = raw_data.withColumnRenamed("_c4","text")

raw_data.show(5)
# Out:
# +----------+--------------------+--------+-----------+--------------------+--------+
# |       _c0|                 _c1|     _c2|        _c3|                text|polarity|
# +----------+--------------------+--------+-----------+--------------------+--------+
# |2326691715|Thu Jun 25 07:23:...|NO_QUERY|  androslee|aw snap, win7 dis...|     0.0|
# |2050459563|Fri Jun 05 18:42:...|NO_QUERY|ShannonRaeP|not having a good...|     0.0|
# |2257676117|Sat Jun 20 14:42:...|NO_QUERY|    sweett8|watchinG paRis hi...|     0.0|
# |2205642391|Wed Jun 17 05:09:...|NO_QUERY| nuttychris|@nelsonmaud fucki...|     0.0|
# |2014908397|Wed Jun 03 03:05:...|NO_QUERY|   mishok13|huh, pylint doesn...|     0.0|
# +----------+--------------------+--------+-----------+--------------------+--------+
# only showing top 5 rows

# %%
# Let's start with getting some data to test our RegEx on
raw_data.select("text").show(50, False)
# Out:
# +-----------------------------------------------------------------------------------------------------------------------------------------+
# |text                                                                                                                                     |
# +-----------------------------------------------------------------------------------------------------------------------------------------+
# |aw snap, win7 discounts tomorrow?  goodbye checkbook   http://tr.im/pIT5                                                                 |
# |not having a good day today feeling depressed and un motivated all alone all day today                                                   |
# |watchinG paRis hiltOn my new BFF [wii] haha anD jOb                                                                                      |
# |@nelsonmaud fucking amazing just got shit loadsa work to do  haha                                                                        |
# |huh, pylint doesn't handle yield expressions, crashes --&gt; my flymake+pylint combo can not be used for coroutines                      |
# |wants to get out but it's a little late                                                                                                  |
# |@littlecharva Thought I noticed some chemistry.                                                                                          |
# |Finally figured out how to make Roller coaster tycoon HQ. but it's small                                                                 |
# |watchin TV.... but it's alomst time to go to sleep  miley u rock ;) peace                                                                |
# |@tommcfly can you wish happy birthday @milaitsme ? PLEASE, stop reply to demi and wish happy birthday to her                             |
------------------------------------------------------------------------------------------------------------------------------+
# only showing top 50 rows

# %%
# extract twitter user names/handles to the output column `user_mentioned`

user_regex = r"(@\w{1,15})"

# %%
def regexp_extract_all(
    df: DataFrame,
    regex: str,
    no_of_extracts: int,
    input_column_name: str,
    output_column_name: str = "output",
    empty_array_replace: bool = True,
):
    
    repeats = range(0, no_of_extracts)
    
    # A set of interim columns are created that will be dropped afterwards
    match_columns = [f"___{r}___" for r in repeats]
    
    # Apply regexp_extract an r number of times
    for r in repeats:
        df = df.withColumn(
            match_columns[r],
            f.regexp_extract(
                f.col(input_column_name),
                # the input regex string is amended with ".*?" 
                # and repeated an r number of times
                # r needs to be +1 as matching groups are 1-index
                "".join([f"{regex}.*?" for i in range(0, r+1)]),
                r+1,
            ),
        )

    # Create a distinct array, all empty strings removed
    df = df.withColumn(
        output_column_name,
        f.array_remove(f.array_distinct(f.array(match_columns)), ""),
    )

    # Replace empty string with None if empty_array_replace was set 
    if empty_array_replace:
        df = df.withColumn(
            output_column_name,
            f.when(f.size(output_column_name) == 0, f.lit(None)).otherwise(
                f.col(output_column_name)
            ),
        )
    
    # Drop interim columns
    for c in match_columns:
        df = df.drop(c)

    return df

# %%
hashtag_regex = "(#\w{1,})"

temp_df = raw_data.filter(f.instr(f.col("text"), "#") > 4)

# %%
hashtag_replace_regex = "#(\w{1,})"

# %%
url_regex=r"((https?|ftp|file):\/{2,3})+([-\w+&@#/%=~|$?!:,.]*)|(www.)+([-\w+&@#/%=~|$?!:,.]*)"
email_regex=r"[\w.-]+@[\w.-]+\.[a-zA-Z]{1,}"

# %%
from pyspark.sql.functions import udf
import html

@udf
def html_unescape(s: str):
    return html.unescape(s)

# %%
def regexp_extract_all(
    df: DataFrame,
    regex: str,
    no_of_extracts: int,
    input_column_name: str,
    output_column_name: str = "output",
    empty_array_replace: bool = True,
):
    
    repeats = range(0, no_of_extracts)

    # A set of interim columns are created that will be dropped afterwards
    match_columns = [f"___{r}___" for r in repeats]

    # Apply regexp_extract an r number of times
    for r in repeats:
        df = df.withColumn(
            match_columns[r],
            f.regexp_extract(
                f.col(input_column_name),
                # the input regex string is amended with ".*?"
                # and repeated an r number of times
                # r needs to be +1 as matching groups are 1-indexed
                "".join([f"{regex}.*?" for i in range(0, r + 1)]),
                r + 1,
            ),
        )

    # Create a distinct array, all empty strings removed
    df = df.withColumn(
        output_column_name,
        f.array_remove(f.array_distinct(f.array(match_columns)), ""),
    )

    # Replace empty string with None if empty_array_replace was set
    if empty_array_replace:
        df = df.withColumn(
            output_column_name,
            f.when(f.size(output_column_name) == 0, f.lit(None)).otherwise(
                f.col(output_column_name)
            ),
        )

    # Drop interim columns
    for c in match_columns:
        df = df.drop(c)

    return df


@udf
def html_unescape(s: str):
    if isinstance(s, str):
        return html.unescape(s)
    return s


def cleaning_process(df: DataFrame):
    url_regex = r"((https?|ftp|file):\/{2,3})+([-\w+&@#/%=~|$?!:,.]*)|(www.)+([-\w+&@#/%=~|$?!:,.]*)"
    email_regex = r"[\w.-]+@[\w.-]+\.[a-zA-Z]{1,}"
    user_regex = r"(@\w{1,15})"
    hashtag_regex = "(#\w{1,})"
    hashtag_replace_regex = "#(\w{1,})"

    # Cleaning process:

    # 1. Extract user mentions and hashtags
    df = regexp_extract_all(df, user_regex, 6, "text", "users_mentioned", True)
    df = regexp_extract_all(df, hashtag_regex, 6, "text", "hashtags", True)

    # 2. Remove email addresses, URLs, and user mentions
    # Order is important here
    df = (
        df
        .withColumn("original_text", f.col("text"))
        .withColumn("text", f.regexp_replace(f.col("text"), url_regex, ""))
        .withColumn("text", f.regexp_replace(f.col("text"), email_regex, ""))
        .withColumn("text", f.regexp_replace(f.col("text"), user_regex, ""))

    )

    # 3. Extract words from hashtags
    df = df.withColumn(
        "text", f.regexp_replace(f.col("text"), hashtag_replace_regex, "$1")
    )

    # 4. Unescape HTML
    df = df.withColumn("text", html_unescape("text"))

    # 5. Remove non - words
    df = df.withColumn(
        "text", f.regexp_replace(f.col("text"),r"[^A-za-z]", " ")
    )
    

    # 6. Remove multiple white spaces
    df = df.withColumn(
        "text", f.regexp_replace(f.col("text"),r"[\s]{2,}", " ")
    )

    # 7. To Lowercase
    df = df.withColumn(
        "text", f.lower(f.col("text")) 
    )

    # 8. Trimming Text
    df = df.withColumn(
        "text", f.trim(f.col("text")) 
    )

    # 9. Drop all rows with no data in text after cleaning steps were applied
    df = df.filter(f.col("text") != "").na.drop(subset="text")

    
    return df

schema = """
polarity STRING COMMENT "the polarity of the tweet (0 = negative, 2 = neutral, 4 = positive)",
id INT COMMENT "the id of the tweet (2087)",
date STRING COMMENT "the date of the tweet (Sat May 16 23:58:44 UTC 2009)",
query STRING COMMENT "the query (lyx). If there is no query, then this value is NO_QUERY.",
user string COMMENT "the user that tweeted (robotickilldozr)",
text string COMMENT "the text of the tweet (Lyx is cool)"
"""

clean_data = cleaning_process(raw_data)

clean_data.select("text").show(250, False)
# Out:
# +--------------------------------------------------------------------------------------------------------------------------------------+
# |text                                                                                                                                  |
# +--------------------------------------------------------------------------------------------------------------------------------------+
# |aw snap win discounts tomorrow goodbye checkbook                                                                                      |
# |not having a good day today feeling depressed and un motivated all alone all day today                                                |
# |watching paris hilton my new bff [wii] haha and job                                                                                   |
# |fucking amazing just got shit loadsa work to do haha                                                                                  |
# |huh pylint doesn t handle yield expressions crashes my flymake pylint combo can not be used for coroutines                            |
# |wants to get out but it s a little late                                                                                               |
# |thought i noticed some chemistry                                                                                                      |
# |finally figured out how to make roller coaster tycoon hq but it s small                                                               |
# |watchin tv but it s alomst time to go to sleep miley u rock peace                                                                     |
# |can you wish happy birthday please stop reply to demi and wish happy birthday to her                                                  |
# |i need a date to zombie prom in portland oregon my date canceled want and could you be my date                                        |
# |let me know how you get on or i ll spend all day worrying                                                                             |
# |just tried tweeting some technical stuff but uffff hectic                                                                             |
# |all those questionings were pointless simple answer all along did not like me at all hard lesson                                      |
# |okay so still no school                                                                                                               |
# |lol yeah i aint had no service at the lake besides that i cant get twitter sms to work and theres no app my fone either               |
# |spent the night at my mother in law s place i like her a lot but the beds down here just don t do it for me not good sleep            |
# |can t go tonight no sitter                                                                                                            |
# |it s so unfair no one is wirting me                                                                                                   |
# |i know my mom told me but i was at wrk why i bet it wasn t more hideous than work i put in my weeks yesterday                         |
# |going back to san jos                                                                                                                 |
# |so even tho it was just a preseason game i hate losing our season ended with a l to detroit and our preseason started with an l to det|
# |just tried it you can t upload animated gifs any more icon or background so anyone who s got one needs to hang on to it               |
# |girl i cant do it on step into the vogue and im looking like don king                                                                 |
# |not feeling good                                                                                                                      |
# |this video is not available outside the us what did i miss                                                                            |
# |in the comments people are saying burn her alive i say burn a tiny bit of her skin everyday for as long as she lives                  |
# |hahaha im not sure cuz jordins the only person who i tried talkin several times and she never responds                                |
# |pot noodles aren t as spicy as they used to be                                                                                        |
# |it s going to be a site with a bunch of desktop and web apps there s a lot more to it but i only have characters                      |
# |luccky i have the rest of this year then next year as well                                                                            |
# |almost home more to do than not do bummer                                                                                             |
# |says my head is about to burst plurk got me insane idiot tears help me please im not use to it                                        |
# |lol u know what i meant shiiaatt gimmie a break had a long night                                                                      |
# |so i haven t tweeted or is it twittered in a few weeks have been swamped at work and working at home evy night                        |
# |went to the church for sat night gathering crumbs not tonight                                                                         |
# |i m sick of school it s time to go home and go to the lake                                                                            |
# |fuccccckkk watching movies like this alone is really not a good idea                                                                  |
# |fuun u know ive never been there before i wanna go                                                                                    |
# |not sure if i should keep going out with toby anymore                                                                                 |
# |sasha u made me miss my iguana but nowadays the iguanas in malaysia are not as green as it used to be                                 |
# |my showers always so cold gotta wait minutes until i can use my mum dad s too                                                         |
# |im thinkin about doing that i loved my storm before i got this replacement tho                                                        |
# |watching bb cairon got evicted badd times n                                                                                           |
# |that s cute haha jesse is such a meanie though and saying i suck                                                                      |
# |one day before being left alone in cambridge out now to shop for groceries for a nice homecooked meal though                          |
# |couldn t view it is this the same one vic posted the one where he looks is he taller that you                                         |
# |virginia i hope you do another movie in memphis the city miss you                                                                     |
# |are u kidding me on the th goal                                                                                                       |
# |eww i miss to see them lg ape lu                                                                                                      |
# |damn it i waited too long to buy tickets for the show tomorrow night and now it s sold out                                            |
# |i know right sexy stewy i miss the hair too but she must rock for jj                                                                  |
# |you okay                                                                                                                              |
# |really wish i was at relay for life noww startinq to qet super boredd                                                                 |
# |can t help it leaving the door open cool cool air stupid bugs stay away                                                               |
# |why did i get up at when i had the opportunity to get up at am a                                                                      |
# |for days in japan including hotel and round trip i can dream                                                                          |
# |patiently waiting for max at his piano class while studying organic chemistry why did i take this summer class why                    |
# |hahahaha my leggings and my hofstra shirt i miss it there                                                                             |
# |no didn t have a way to record it no dvr they re probably gonna show highlights of the parade or just watch it online                 |
# |yes yes they are i saw a chick the other day with an outtie belly button and a belly button ring it made me sad                       |
# |limping around all day guess i ll be swimmimng tomorrow rest my leg for awhile                                                        |
# |why is it complicated medyo may pagka facebook                                                                                        |
# |ur using twitterfon that means u have an iphone                                                                                       |
# |l i still can t get enough of ur song around the way girl the s were the best the music will never b the same                         |
# |my fingers are in bits from guitar lucky this is touch screen ] as for my fingers they re not touching that guitar for a while        |
# |aww laura robson s out of the open to sandra zaniewska bad luck still wimbledon soon                                                  |
# |weeks later and googlebot still hasn t indexed a website of mine even though webmastertools gives no erros hmm strange                |
# |would like to thank the gobshites upstairs for finally going to sleep most annoying night here ever                                   |
# |weather picked the perfect weekend to rain all day i finally had some time to be outdoors                                             |
# |summmer just woke up raining out i wanna go for a walk                                                                                |
# |way too early ugghhh so tired getting ready then schoool kill me now                                                                  |
# |bright eyes just came on shuffle and i started to cry i miss my brother                                                               |
# |ugh monday                                                                                                                            |
# |all work and no sleep make leia a dull girl                                                                                           |
# |sounds like fun too bad i dont draw                                                                                                   |
# |just woke up no school i lost followers                                                                                               |
# |gtretweet i don t know i didn t expect to see but yeah they have whale watching groups i thi                                          |
# |pretty sure i have the signs of appendicitis                                                                                          |
# |lmao yeah that s me                                                                                                                   |
# |rip farrah fawcett more losses to cancer                                                                                              |
# |well done if u get that mp version pls can you make it available as a download somewhere some of us didnt get to c it                 |
# |house is clean now i have to iron just counted golf shirts and there s a whole lot more in the pile where are you                     |
# |apparently architecture is piss easy xd btw did i leave my irn bru at yours                                                           |
# |i m so sorry about your dog i know how hard it is                                                                                     |
# |ouch                                                                                                                                  |
# |the gums around the ring connected to my upper right molar is swelling can t bite can t chew super irritating and painful             |
# |se me rompio la teleeeeeee nooooooo mi sony why                                                                                       |
# |ok seriously i hate this phone its totally gay even the keypad sounds are really gay someone save me                                  |
# |sleep deprived one test one quizam and a final                                                                                        |
# |friday morning bored hello d my entire gtalk buddy list online no one replied except the language translator bot                      |
# |doesnt know why my picture wont show up                                                                                               |
# |hugsregardless                                                                                                                        |
# |and lost my cell phone in the process                                                                                                 |
# |feeling very sick                                                                                                                     |
# |she left bucks from her piggy bank fund me plz                                                                                        |
# |had a nice afaternoon shame that my left leg hurts                                                                                    |
# |i wish i had sparkle on dvd but i can t find it anywhere if you can just remember my bday great gift                                  |
# |last full day going to the beach massages pool and out to dinner                                                                      |
# +--------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 250 rows

# %%
raw_data.count()
# Out:
# 1600000

# %%
clean_data.count()
# Out:
# 1596236

# %%
clean_data.filter("text == ''").show(1000)
# Out:
# +---+---+---+---+----+--------+---------------+--------+-------------+
# |_c0|_c1|_c2|_c3|text|polarity|users_mentioned|hashtags|original_text|
# +---+---+---+---+----+--------+---------------+--------+-------------+
# +---+---+---+---+----+--------+---------------+--------+-------------+

# %%
clean_data = clean_data.select(["text","polarity"])
clean_data.limit(10).toPandas()
# Out:
#                                                 text  polarity
# 0   aw snap win discounts tomorrow goodbye checkbook       0.0
# 1  not having a good day today feeling depressed ...       0.0
# 2  watching paris hilton my new bff [wii] haha an...       0.0
# 3  fucking amazing just got shit loadsa work to d...       0.0
# 4  huh pylint doesn t handle yield expressions cr...       0.0
# 5            wants to get out but it s a little late       0.0
# 6                   thought i noticed some chemistry       0.0
# 7  finally figured out how to make roller coaster...       0.0
# 8  watchin tv but it s alomst time to go to sleep...       0.0
# 9  can you wish happy birthday please stop reply ...       0.0

# %%
clean_data.write.parquet(CLEAN_PATH)

# %%
spark.stop()
